# %%
#1.Find the error in the following Python code:
import math 
print(math.sqrt(16)) # M was capital letter , corrected m as small and ran the code
# Out:
# 4.0

# %%
#2.Find the error in the following Python code:

# outside of the function we are assigning the x variable with the value 10, but we are trying to print the local variable x inside the function for
# using print() that's why unbound local error issues we faced, so we have to mark as global variable inside the function, then it will print the 
# correct output.

def my_function():
    global x; 
    x += 5 
    print(x)
x = 10
my_function()
# Out:
# 15

# %%
#3.x = 5
# x = 5 declared with comment section, so python won't consider and also in print statement declared as string. It will consider as it is double quptes
#if x = 10:
    #print("x is 10") 

# So the corrected code is
x = 5
if x == 10:
    print(x, " is 10")
else:
    print(x, " is not 10")
# Out:
# 5  is not 10

# %%
#4.
# Declared list of numbers non sequence order and assigning a variable as numbers to the list of numbers in the list.
# And instead of sorting individually, Here we are trying to sort inside the print() function, So the output is shwoing in console as "None".
# First we have to sort the list then we have to print the sorted list.
numbers = [5, 3, 8, 2]
numbers.sort()
print(numbers)
# Out:
# [2, 3, 5, 8]

# %%
#5.
# Inside the function, written n * n but did not return it or print it.
# Inside a function, print() function are missing
# Outside of the def, directly calling the function wwith arguments print() function, Inside function we are not return function or not printing anything.
# so that's why we are seeing "None" in output console.
def square(n):
    return n * n
print(square(4))
# Out:
# 16

# %%
#6.
# Tuple is immutable, once we create an tuple object we can't able to change or modify content. We can call the elements using index.
my_tuple = (1, 2, 3)
#my_tuple[1]
print(my_tuple[1])
# Out:
# 2

# %%
#7.
# Two variables are declared name and age, but in print() entire sentence declared inside double quotes.
name = "Alice"
age = 25
#print("My name is %s and I am %d years old" % (name))
print("My name is {}  and I am {} years old".format(name, age))
# Out:
# My name is Alice  and I am 25 years old

# %%
#8.
# is mean for address comparison
# == mean for content comparison, Here we are comparing two contents not address, So use == instead of is.
a = [1, 2, 3]
b = [1, 2, 3]
if a == b:
    print("Lists are equal")
# Out:
# Lists are equal

# %%
#9.
# descending to ascending numbers printing is not possible and also decrements are missing, Once we add the code will run
for i in range(5, 1, -1):
    print(i)
# Out:
# 5
# 4
# 3
# 2

# %%
#10.
# It's combination of key value pair, first key is name it's in string then inside print function also call with string then only value will display
# in console.
student = {"name": "John", "age": 20}
print(student["name"])
# Out:
# John
