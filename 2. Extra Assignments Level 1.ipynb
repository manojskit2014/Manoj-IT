# %% [markdown]
# #print Statement - HOPE AI

# %%
print("HOPE AI")
# Out:
# HOPE AI

# %% [markdown]
# # Buy Input
# #Enter your institute name? : HOPE AI

# %%
name =input("Enter Your Institute Name ? : ")
print(name)
# Out:
# Enter Your Institute Name ? :  Hope AI
# Hope AI

# %% [markdown]
# # Buy Inputs
# Enter your name: Raj
# Enter your age: 15
# Enter your school name: Guru school
# Enter your drgree: B.E CSE

# %%
name =input("Enter Your Name : ")
age =input("Enter Your Age : ")
school_name =input("Enter Your School Name : ")
degree =input("Enter Your Degree : ")
print(name+" "+age+" "+school_name+" "+degree)
# Out:
# Enter Your Name :  Manoj
# Enter Your Age :  34
# Enter Your School Name :  K S R College of Technology
# Enter Your Degree :  B.Tech
# Manoj 34 K S R College of Technology B.Tech

# %% [markdown]
# # Addition
# a= 43
# b= 34
# add = 77

# %%
a = 43
b = 34
add = a + b
print(add)
# Out:
# 77

# %% [markdown]
# # Subtraction
# a= 43
# b= 34
# Sub = 9

# %%
a = int(input("Enter 1st Number :"))
b = int(input("Enter 2nd Number :"))
sub = a - b
print("The Subtraction is :", sub)
# Out:
# Enter 1st Number : 43
# Enter 2nd Number : 34
# The Subtraction is : 9

# %% [markdown]
# # Multiplication
# a= 63
# b= 97
# Mul = 6111

# %%
a = int(input("Enter 1st Number :"))
b = int(input("Enter 2nd Number :"))
print("The Multiplication is :", a * b)
# Out:
# Enter 1st Number : 63
# Enter 2nd Number : 97
# The Multiplication is : 6111

# %% [markdown]
# # Division
# a= 76
# b= 31
# Float Div = 2.4516129032258065

# %%
a = int(input("Enter 1st Number :"))
b = int(input("Enter 2nd Number :"))
float_div = a / b
print(float_div)
# Out:
# Enter 1st Number : 76
# Enter 2nd Number : 31
# 2.4516129032258065

# %% [markdown]
# # Floor Division
# a= 76
# b= 31
# Floor Div = 2

# %%
a = int(input("Enter 1st Number :"))
b = int(input("Enter 2nd Number :"))
floor_div = a // b
print(floor_div)
# Out:
# Enter 1st Number : 76
# Enter 2nd Number : 31
# 2

# %% [markdown]
# # Modulo
# a= 76
# b= 31
# Modulo = 14

# %%
a = int(input("Enter 1st Number :"))
b = int(input("Enter 2nd Number :"))
modulo = a % b
print(modulo)
# Out:
# Enter 1st Number : 76
# Enter 2nd Number : 31
# 14

# %% [markdown]
# # Power
# a= 4
# b= 4
# Power = 256

# %%
a = int(input("Enter 1st Number :"))
b = int(input("Enter 2nd Number :"))
power = a ** b
print(power)
# Out:
# Enter 1st Number : 4
# Enter 2nd Number : 4
# 256
