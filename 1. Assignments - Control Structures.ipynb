# %% [markdown]
# 1. Welcome to Assignment - 1

# %%
print("Welcome to Assignment - 1")
# Out:
# Welcome to Assignment - 1

# %% [markdown]
# 2. Num1=10
#    Num2=30
#    Add=40

# %%
Num1 = int(input("Enter First Number :"))
Num2 = int(input("Enter Second Number :"))
Add = Num1 + Num2
print("The Answer is :", Add)
# Out:
# Enter First Number : 10
# Enter Second Number : 30
# The Answer is : 40

# %% [markdown]
# 3. Enter the BMI Index:34
#    Very Overweight

# %% [markdown]
# BMI Categories for height: 1.75 m (175 cm) - using metric formula, while entering weight in kilograms give height in meters.
#
# Under Weight: 0.0 – 56.3 kg
# Normal Weight: 56.4 – 76.2 kg
# Over Weight: 76.3 – 91.6 kg
# OBESITY (Class 1): 91.7 – 106.9 kg
# OBESITY (Class 2): 107.0 – 122.2 kg
# OBESITY (Class 3): ≥ 122.3 kg

# %%
weight = float(input("Enter your weight (kg) :"))
height = float(input("Enter your height (cm) :"))
BMI = weight / (height ** 2)
print("The Output is : ", BMI)
if (BMI <= 18.4):
    print("You are Under Weight")
elif (BMI <= 24.9):
    print("You are Normal Weight")
elif (BMI <= 29.9):
    print("You are Over Weight")
elif (BMI <= 34.9):
    print("You are OBESITY (Class 1)")
elif (BMI <= 39.9):
    print("You are OBESITY (Class 2)")
else:
    print("You are OBESITY (Class 3)")
# Out:
# Enter your weight (kg) : 125
# Enter your height (cm) : 1.75
# The Output is :  40.816326530612244
# You are OBESITY (Class 3)

# %% [markdown]
# Category	Weight (lb) Range - using imperial formula, while entering weight in lb or pounds give height in inches.
# Under Weight	≤ 124 lb
# Normal Weight	124.1 – 168 lb
# Over Weight	168.1 – 202 lb
# OBESITY (Class 1)	202.1 – 238 lb
# OBESITY (Class 2)	238.1 – 272 lb
# OBESITY (Class 3)	≥ 272.1 lb

# %%
weight = float(input("Enter your weight (lb/pounds) :"))
height = float(input("Enter your height (inch) :"))
BMI = (weight / (height ** 2)) * 703
print("The Output is : ", BMI)
if (BMI <= 18.4):
    print("You are Under Weight")
elif (BMI <= 24.9):
    print("You are Normal Weight")
elif (BMI <= 29.9):
    print("You are Over Weight")
elif (BMI <= 34.9):
    print("You are OBESITY (Class 1)")
elif (BMI <= 39.9):
    print("You are OBESITY (Class 2)")
else:
    print("You are OBESITY (Class 3)")
# Out:
# Enter your weight (lb/pounds) : 275
# Enter your height (inch) : 69
# The Output is :  40.60596513337534
# You are OBESITY (Class 3)
