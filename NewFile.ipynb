# %%
from fiveFunctions import AllFiveFunctions

# %%
AllFiveFunctions.subFields()
# Out:
# Sub-fields in AI are :
# Machine Learning
# Neural Networks
# Vision
# Robotics
# Speech Processing
# Natural Language Processing

# %%
AllFiveFunctions.oddEven()
# Out:
# Enter the Number :  5
# The given number is an Odd Number
# 'Odd Number'

# %%
AllFiveFunctions.Eligible()
# Out:
# Enter Your Gender :  Male
# Enter the Age :  25
# Male Eligible For Marriage

# %%
AllFiveFunctions.percentage()
# Out:
# Subject1 =  98
# Subject2 =  87
# Subject3 =  95
# Subject4 =  95
# Subject5 =  93
# Total :  468
# Percentage :  93.6

# %%
AllFiveFunctions.triangle()
# Out:
# Enter Height :  32
# Enter Breadth : 34
# The Area of Triangle is :  544.0
# **************************************
# Enter Height1 :  2
# Enter Height2 :  4
# Enter Breadth1 : 4
# The Perimeter of Triangle is7 :  10
