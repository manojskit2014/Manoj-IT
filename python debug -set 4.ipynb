# %%
#1.Identify and fix the syntax error in the following code:
#age = 18
#if age >= 18
 #   print("You are eligible to vote")

age = 18
if age >= 18: # colon missed
    print("You are eligible to vote")
# Out:
# You are eligible to vote

# %%
#2.Question:
#What error will occur in the following code?
#def greet():
 #   print("Hello, World!")
#greet_user()

def greet(): # function name defined as wrong
    print("Hello, World!")
greet()
# Out:
# Hello, World!

# %%
#3.Identify the error in this code:
#name = "Alice"
#age = 25
#print("My name is " + name + " and I am " + age + " years old.")

name = "Alice"
age = 25
print("My name is {} and I am {} years old".format(name,age))
# Out:
# My name is Alice and I am 25 years old

# %%
#4.Question:
#What will happen when you run this code?

#a = 10
#b = 0
#result = a / b
#print(result)

a = 10 # Anything divisible by zero, zero division error occurred
b = 5
result = a / b
print(result)
# Out:
# 2.0

# %%
#5.What error will occur in the following code?
#num = int("xyz")
#print(num)

num = int("123") # Above code, type error able to concantenate string with numerical not string with alphabets
print(num)
# Out:
# 123

# %%
#6.Identify the issue in this code:
#data = {"name": "John", "age": 30}
#print(data["city"])

data = {"name": "John", "age": 30} # There was no key defined city
print(data["name"])
# Out:
# John

# %%
#7.What will happen when you run this code?
#num = 1
#while num < 5:
 #   print(num)

num = 1 # increment was not declared
while num < 5:
    print(num)
    num += 1
# Out:
# 1
# 2
# 3
# 4

# %%
#8.What is wrong with this code?

#fruits = ("apple", "banana", "cherry")
#print(fruits[3])

fruits = ("apple", "banana", "cherry") # trying to access 4th element but 3 elements only declared, will get index out of range error
print(fruits[2])
# Out:
# cherry

# %%
#9.What will happen when you run this code?

#text = "hello world"
#text.append("!")

text = "hello world"
text1 = "!"
print(text + text1)
# Out:
# hello world!

# %%
#10.What is wrong with the following code?

#import randoms
#print(randoms.randint(1, 10))

import random # there was no any randoms function 
print(random.randint(1, 10))
# Out:
# 3
